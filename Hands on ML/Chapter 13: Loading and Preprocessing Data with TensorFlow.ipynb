# %%
from sklearn.datasets import fetch_california_housing  
import tensorflow as tf

# %%
data = fetch_california_housing()
data.keys()
# Out:
# ...
# dict_keys(['data', 'target', 'feature_names', 'DESCR'])

# %%
california = np.c_data['target']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-da72e05faa57> in <module>()
#       1 california = np.concatenate([data['data'], np.vstack(data['target'])], axis=1)
# ----> 2 california = np.concatenate([[data['feature_names']], california])
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 8 and the array at index 1 has size 9

# %%
data['data'].sh
# Out:
# (20640, 8)

# %%
data['feature_names']
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude']
